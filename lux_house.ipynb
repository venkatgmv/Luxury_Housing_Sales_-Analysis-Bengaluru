# %%
import pandas as pd

# %%
df=pd.read_csv("D:\Guvi_projects\Luxury_house\Luxury_Housing_Bangalore.csv")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\G'
# <>:1: SyntaxWarning: invalid escape sequence '\G'
# C:\Users\VENKATARAMAN\AppData\Local\Temp\ipykernel_21168\1136132899.py:1: SyntaxWarning: invalid escape sequence '\G'
#   df=pd.read_csv("D:\Guvi_projects\Luxury_house\Luxury_Housing_Bangalore.csv")

# %%
df
# Out:
#        Property_ID       Micro_Market Project_Name Developer_Name  \
# 0       PROP000001      Sarjapur Road    Project_0            RMZ
# 1       PROP000002        Indiranagar    Project_1    Puravankara
# 2       PROP000003  Bannerghatta Road    Project_2   Tata Housing
# 3       PROP000004       bellary road    Project_3        Embassy
# 4       PROP000005        Koramangala    Project_4        SNN Raj
# ...            ...                ...          ...            ...
# 100995  PROP004730       BELLARY ROAD  Project_229        Embassy
# 100996  PROP059810       Bellary Road  Project_309        Brigade
# 100997  PROP065099        HENNUR ROAD   Project_98            RMZ
# 100998  PROP093022        rajajinagar   Project_21        Embassy
# 100999  PROP023826         whitefield  Project_325     L&T Realty
#
#         Unit_Size_Sqft Configuration     Ticket_Price_Cr Transaction_Type  \
# 0               4025.0          4bhk  12.750846039118798          Primary
# ...

# %%
df.describe()
# Out:
#        Unit_Size_Sqft  Connectivity_Score  Amenity_Score  \
# count    90954.000000       101000.000000   90910.000000
# mean      5972.274765            6.992619       7.503663
# std       1783.397836            1.731757       1.440758
# min         -1.000000            4.000031       5.000224
# 25%       4477.250000            5.494526       6.260329
# 50%       5990.000000            6.985805       7.499123
# 75%       7497.000000            8.490000       8.752207
# max       8999.000000            9.999970       9.999865
#
#        Locality_Infra_Score  Avg_Traffic_Time_Min
# count         101000.000000         101000.000000
# mean               7.498426             67.182921
# std                1.443128             30.271611
# min                5.000013             15.000000
# 25%                6.247954             41.000000
# 50%                7.495614             67.000000
# 75%                8.749824             93.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101000 entries, 0 to 100999
# Data columns (total 18 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Property_ID           101000 non-null  object
#  1   Micro_Market          101000 non-null  object
#  2   Project_Name          101000 non-null  object
#  3   Developer_Name        101000 non-null  object
#  4   Unit_Size_Sqft        90954 non-null   float64
#  5   Configuration         101000 non-null  object
#  6   Ticket_Price_Cr       90981 non-null   object
#  7   Transaction_Type      101000 non-null  object
#  8   Buyer_Type            101000 non-null  object
#  9   Purchase_Quarter      101000 non-null  object
#  10  Connectivity_Score    101000 non-null  float64
#  11  Amenity_Score         90910 non-null   float64
#  12  Possession_Status     101000 non-null  object
#  13  Sales_Channel         101000 non-null  object
# ...

# %%
df.isnull()
# Out:
#         Property_ID  Micro_Market  Project_Name  Developer_Name  \
# 0             False         False         False           False
# 1             False         False         False           False
# 2             False         False         False           False
# 3             False         False         False           False
# 4             False         False         False           False
# ...             ...           ...           ...             ...
# 100995        False         False         False           False
# 100996        False         False         False           False
# 100997        False         False         False           False
# 100998        False         False         False           False
# 100999        False         False         False           False
#
#         Unit_Size_Sqft  Configuration  Ticket_Price_Cr  Transaction_Type  \
# 0                False          False            False             False
# ...

# %%
df.isnull().sum()
# Out:
# Property_ID                 0
# Micro_Market                0
# Project_Name                0
# Developer_Name              0
# Unit_Size_Sqft          10046
# Configuration               0
# Ticket_Price_Cr         10019
# Transaction_Type            0
# Buyer_Type                  0
# Purchase_Quarter            0
# Connectivity_Score          0
# Amenity_Score           10090
# Possession_Status           0
# Sales_Channel               0
# NRI_Buyer                   0
# Locality_Infra_Score        0
# Avg_Traffic_Time_Min        0
# Buyer_Comments          18287
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(1000)

# %%
df.drop_duplicates(inplace=True)

# %%
df.sample(5)
# Out:
#       Property_ID       Micro_Market Project_Name Developer_Name  \
# 96419  PROP096420  bannerghatta road  Project_419            RMZ
# 36503  PROP036504      sarjapur road    Project_3        Brigade
# 81668  PROP081669          Yelahanka  Project_168     L&T Realty
# 24654  PROP024655    electronic city  Project_154    Puravankara
# 60679  PROP060680    ELECTRONIC CITY  Project_179        Embassy
#
#        Unit_Size_Sqft Configuration     Ticket_Price_Cr Transaction_Type  \
# 96419          8904.0          4BHK   9.122187790965816        Secondary
# 36503          4102.0         5Bhk+  13.057158382712501          Primary
# 81668             NaN          3bhk  12.761029847282783          Primary
# 24654          3102.0          3Bhk  11.301855182699583        Secondary
# 60679          8465.0          4BHK  15.122220438527918          Primary
#
#             Buyer_Type Purchase_Quarter  Connectivity_Score  Amenity_Score  \
# ...

# %%
df['Ticket_Price_Cr']=df['Ticket_Price_Cr'].str.replace('Cr','',regex=False).str.strip().str.replace('Rs','').str.replace('₹','')
#remove 'Cr','Rs','₹' and extra spaces from the column
df['Ticket_Price_Cr']=pd.to_numeric(df['Ticket_Price_Cr'],errors='coerce')
#convert the column to numeric, setting errors to NaN

# %%
df['Ticket_Price_Cr']
# Out:
# 0        12.750846
# 1        16.292152
# 2        10.517724
# 3         9.396367
# 4        15.345392
#            ...
# 99995    10.185193
# 99996    12.272081
# 99997    13.730179
# 99998    10.363989
# 99999    10.415617
# Name: Ticket_Price_Cr, Length: 100000, dtype: float64

# %%
df['Unit_Size_Sqft'] = df['Unit_Size_Sqft'].fillna(df['Unit_Size_Sqft'].mean())
# fill values missed in 'Unit_Size_Sqft' with the mean of the column
df['Ticket_Price_Cr'] = df['Ticket_Price_Cr'].fillna(df['Ticket_Price_Cr'].mean())
# Fill values missed in 'Ticket_Price_Cr' with the mean of the column
df['Amenity_Score'] = df['Amenity_Score'].fillna(df['Amenity_Score'].median())
# Fill values missed in 'Amenity_Score' with the median of the column
df['Buyer_Comments'] = df['Buyer_Comments'].fillna("No Comments")
# fill values missed in 'Buyer_Comments' with "No Comments"

# %%
df
# Out:
#       Property_ID       Micro_Market Project_Name Developer_Name  \
# 0      PROP000001      Sarjapur Road    Project_0            RMZ
# 1      PROP000002        Indiranagar    Project_1    Puravankara
# 2      PROP000003  Bannerghatta Road    Project_2   Tata Housing
# 3      PROP000004       bellary road    Project_3        Embassy
# 4      PROP000005        Koramangala    Project_4        SNN Raj
# ...           ...                ...          ...            ...
# 99995  PROP099996       bellary road  Project_495     L&T Realty
# 99996  PROP099997          YELAHANKA  Project_496     L&T Realty
# 99997  PROP099998        rajajinagar  Project_497       Prestige
# 99998  PROP099999        INDIRANAGAR  Project_498        SNN Raj
# 99999  PROP100000        hennur road  Project_499        Embassy
#
#        Unit_Size_Sqft Configuration  Ticket_Price_Cr Transaction_Type  \
# 0              4025.0          4bhk        12.750846          Primary
# ...

# %%
df.dtypes
# Out:
# Property_ID              object
# Micro_Market             object
# Project_Name             object
# Developer_Name           object
# Unit_Size_Sqft          float64
# Configuration            object
# Ticket_Price_Cr         float64
# Transaction_Type         object
# Buyer_Type               object
# Purchase_Quarter         object
# Connectivity_Score      float64
# Amenity_Score           float64
# Possession_Status        object
# Sales_Channel            object
# NRI_Buyer                object
# Locality_Infra_Score    float64
# Avg_Traffic_Time_Min      int64
# Buyer_Comments           object
# dtype: object

# %%
norm_column = ['Micro_Market', 'Developer_Name', 'Configuration',
             'Transaction_Type', 'Buyer_Type', 'Possession_Status',
             'Sales_Channel', 'NRI_Buyer']
# Columns to be normalized using one-hot encoding

# %%
for col in norm_column:
    df[col]=df[col].str.strip().str.title()
# Standardize text data by stripping extra spaces and converting to title case

# %%
df["Price_per_Sqft"] = df["Ticket_Price_Cr"] * 10000000 / df["Unit_Size_Sqft"]
# Create a new column 'Price_per_Sqft' by calculating price per square foot

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 100000 entries, 0 to 99999
# Data columns (total 19 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Property_ID           100000 non-null  object
#  1   Micro_Market          100000 non-null  object
#  2   Project_Name          100000 non-null  object
#  3   Developer_Name        100000 non-null  object
#  4   Unit_Size_Sqft        100000 non-null  float64
#  5   Configuration         100000 non-null  object
#  6   Ticket_Price_Cr       100000 non-null  float64
#  7   Transaction_Type      100000 non-null  object
#  8   Buyer_Type            100000 non-null  object
#  9   Purchase_Quarter      100000 non-null  object
#  10  Connectivity_Score    100000 non-null  float64
#  11  Amenity_Score         100000 non-null  float64
#  12  Possession_Status     100000 non-null  object
#  13  Sales_Channel         100000 non-null  object
# ...

# %%
df
# Out:
#       Property_ID       Micro_Market Project_Name Developer_Name  \
# 0      PROP000001      Sarjapur Road    Project_0            Rmz
# 1      PROP000002        Indiranagar    Project_1    Puravankara
# 2      PROP000003  Bannerghatta Road    Project_2   Tata Housing
# 3      PROP000004       Bellary Road    Project_3        Embassy
# 4      PROP000005        Koramangala    Project_4        Snn Raj
# ...           ...                ...          ...            ...
# 99995  PROP099996       Bellary Road  Project_495     L&T Realty
# 99996  PROP099997          Yelahanka  Project_496     L&T Realty
# 99997  PROP099998        Rajajinagar  Project_497       Prestige
# 99998  PROP099999        Indiranagar  Project_498        Snn Raj
# 99999  PROP100000        Hennur Road  Project_499        Embassy
#
#        Unit_Size_Sqft Configuration  Ticket_Price_Cr Transaction_Type  \
# 0              4025.0          4Bhk        12.750846          Primary
# ...

# %%
# Convert the 'Purchase_Quarter' column to datetime format
df['Purchase_Quarter'] = pd.to_datetime(df['Purchase_Quarter'])
# Extract the quarter from the 'Purchase_Quarter' column and create a new column 'Quarter_Number'
df['Quarter_Number'] = df['Purchase_Quarter'].dt.quarter
# Display the updated DataFrame with the new 'Quarter_Number' column
df['Quarter_Number']
# Out:
# 0        1
# 1        2
# 2        4
# 3        1
# 4        4
#         ..
# 99995    4
# 99996    4
# 99997    3
# 99998    3
# 99999    3
# Name: Quarter_Number, Length: 100000, dtype: int32

# %%
df['Purchase_Quarter'].unique()
# Out:
# <DatetimeArray>
# ['2025-03-31 00:00:00', '2024-06-30 00:00:00', '2023-12-31 00:00:00',
#  '2024-03-31 00:00:00', '2024-12-31 00:00:00', '2023-09-30 00:00:00',
#  '2024-09-30 00:00:00', '2023-06-30 00:00:00']
# Length: 8, dtype: datetime64[ns]

# %%
df
# Out:
#       Property_ID       Micro_Market Project_Name Developer_Name  \
# 0      PROP000001      Sarjapur Road    Project_0            Rmz
# 1      PROP000002        Indiranagar    Project_1    Puravankara
# 2      PROP000003  Bannerghatta Road    Project_2   Tata Housing
# 3      PROP000004       Bellary Road    Project_3        Embassy
# 4      PROP000005        Koramangala    Project_4        Snn Raj
# ...           ...                ...          ...            ...
# 99995  PROP099996       Bellary Road  Project_495     L&T Realty
# 99996  PROP099997          Yelahanka  Project_496     L&T Realty
# 99997  PROP099998        Rajajinagar  Project_497       Prestige
# 99998  PROP099999        Indiranagar  Project_498        Snn Raj
# 99999  PROP100000        Hennur Road  Project_499        Embassy
#
#        Unit_Size_Sqft Configuration  Ticket_Price_Cr Transaction_Type  \
# 0              4025.0          4Bhk        12.750846          Primary
# ...

# %%
df['Transaction_Type'].unique()
# Out:
# array(['Primary', 'Secondary'], dtype=object)

# %%
df['Booking_Flag'] = df['Transaction_Type'].str.lower().map({'primary': 1, 'secondary': 0}) 
# Create a new binary column 'Booking_Flag' based on 'Transaction_Type'

# %%
df['Booking_Flag']
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        0
#         ..
# 99995    1
# 99996    0
# 99997    1
# 99998    1
# 99999    1
# Name: Booking_Flag, Length: 100000, dtype: int64

# %%
df.rename(columns={"Developer_Name": "Builder"}, inplace=True)
# Rename the column 'Developer_Name' to 'Builder'

# %%
df
# Out:
#       Property_ID       Micro_Market Project_Name       Builder  \
# 0      PROP000001      Sarjapur Road    Project_0           Rmz
# 1      PROP000002        Indiranagar    Project_1   Puravankara
# 2      PROP000003  Bannerghatta Road    Project_2  Tata Housing
# 3      PROP000004       Bellary Road    Project_3       Embassy
# 4      PROP000005        Koramangala    Project_4       Snn Raj
# ...           ...                ...          ...           ...
# 99995  PROP099996       Bellary Road  Project_495    L&T Realty
# 99996  PROP099997          Yelahanka  Project_496    L&T Realty
# 99997  PROP099998        Rajajinagar  Project_497      Prestige
# 99998  PROP099999        Indiranagar  Project_498       Snn Raj
# 99999  PROP100000        Hennur Road  Project_499       Embassy
#
#        Unit_Size_Sqft Configuration  Ticket_Price_Cr Transaction_Type  \
# 0              4025.0          4Bhk        12.750846          Primary
# ...

# %%
df.columns
# Out:
# Index(['Property_ID', 'Micro_Market', 'Project_Name', 'Builder',
#        'Unit_Size_Sqft', 'Configuration', 'Ticket_Price_Cr',
#        'Transaction_Type', 'Buyer_Type', 'Purchase_Quarter',
#        'Connectivity_Score', 'Amenity_Score', 'Possession_Status',
#        'Sales_Channel', 'NRI_Buyer', 'Locality_Infra_Score',
#        'Avg_Traffic_Time_Min', 'Buyer_Comments', 'Price_per_Sqft',
#        'Quarter_Number', 'Booking_Flag'],
#       dtype='object')

# %%
# !pip install SQLAlchemy

# %%
# !pip install PyMySQL

# %%
import sys
# !{sys.executable} -m pip install SQLAlchemy

# %%
import sys
# !{sys.executable} -m pip install PyMySQL

# %%
from sqlalchemy import create_engine

host = "localhost",
user = "root",
port = "3306",
database = "lux_house_db",
password = "Venkatgmv227031"

# Create engine
engine = create_engine("mysql+pymysql://root:Venkatgmv227031@localhost:3306/lux_house_db")

# %%
df.to_sql("luxury_housing", engine, if_exists="replace", index=False)
# Out:
# 100000
